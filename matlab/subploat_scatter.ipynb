# %% [markdown]
# ## **`Matplotlib Subplot`**

# %%
import  matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### **Display Multiple Plots**
# With the `subplot()` function you can draw multiple plots in one figure:

# %%
# draw 2 plots in a graph window
x = np.arange(1,100,5)
y1 = np.random.randint(10,110,20)
x2 = np.arange(1,11)

y2 = np.random.randint(10,110,10)
font1 = {'family':'sans','color':'red','size':30}
font2 = {'family':'sans','color':'green','size':10}

# plot 1
plt.subplot(1 ,2,1)
plt.plot(x,y1,marker="o",color="orange",)
plt.title("SALES", fontdict=font2)

# plot 2
plt.subplot(1, 2, 2)
plt.plot(x2,y2,marker="o",color="orange",)
plt.title("Income",fontdict=font2)
plt.suptitle("MY SHOP",fontdict=font1)
plt.show()

# %% [markdown]
# ### **`Matplotlib Scatter`**

# %% [markdown]
# ### Creating Scatter Plots
#   With `Pyplot`, you can use the `scatter()` function to draw a scatter plot.</br>
#   The `scatter()` function plots one dot for each observation. It needs two arrays of the same length, one for the values of the `x-axis`, and one for values on the `y-axis`:

# %%
# day one the age and speed of the 13 car
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)

# day 2 the age and speed of the 15 car
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])

plt.scatter(x,y,color = '#88c999')


plt.show()
